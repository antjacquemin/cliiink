# %% [markdown]
# # Génération des graphiques pour la visualisation des données initiales de la CACPL

# %% [markdown]
# ## Importation des librairies

# %%
import pandas as pd
import json
from sqlalchemy import create_engine
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connexion à la BDD

# %%
fichierConfig = "../../bdd/config.json"

with open(fichierConfig) as fichier:
    config = json.load(fichier)["mysql"]
    
engine = create_engine('mysql+' + config["connector"] + '://' + config["user"] + ":" + config["password"] + "@" + config["host"] + ":" + config["port"] + "/" + config["bdd"], echo=True)

# %% [markdown]
# ## Récupération et préparation des données

# %%
requeteCollecteurs = pd.read_sql_query("SELECT * FROM collecteur JOIN tri ON collecteur.idTri = tri.id LEFT JOIN marque ON collecteur.idMarque = marque.id LEFT JOIN categorie ON collecteur.idCategorie = categorie.id;", engine)
requeteDecheteries = pd.read_sql_query("SELECT * FROM decheterie;", engine)

dataCollecteurs = pd.DataFrame(requeteCollecteurs)
dataDecheteries = pd.DataFrame(requeteDecheteries)


# Renommage des colonnes types pour éviter les confusions (et les erreurs)
cols = []
isTri = True
for column in dataCollecteurs.columns:
    if column == "type":
        if isTri:
            cols.append("typeTri")
            isTri = False
        else:
            cols.append("typeCollecteur")
    else:
        cols.append(column)
dataCollecteurs.columns = cols

# Rajout d'une colonne villes par association code INSEE - ville depuis un dictionnaire (pour faciliter les affichages)
dictVilles = { "06029": "Cannes", "06030": "Le Cannet", "06079": "Mandelieu-la-Napoule", "06085": "Mougins", "06138": "Théoule-sur-Mer"}
for i in dataCollecteurs.index:
    dataCollecteurs.loc[i, "ville"] = dictVilles[dataCollecteurs.loc[i, "codeInsee"]]

dataCollecteurs
# Out:
# 2020-11-04 14:33:05,883 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2020-11-04 14:33:05,885 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 14:33:05,888 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2020-11-04 14:33:05,889 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 14:33:05,892 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2020-11-04 14:33:05,892 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 14:33:05,892 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2020-11-04 14:33:05,892 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 14:33:05,899 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2020-11-04 14:33:05,900 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 14:33:05,902 INFO sqlalchemy.engine.base.Engine SELECT * FROM collecteur JOIN tri ON collecteur.idTri = tri.id LEFT JOIN marque ON collecteur.idMarque = marque.id LEFT JOIN categorie ON collecteur.idCategorie = categorie.id;
# 2020-11-04 14:33:05,903 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-04 14:33:05,990 INFO sqlalchemy.engine.base.Engine SELECT * FROM decheterie;
# 2020-11-04 14:33:05,991 INFO sqlalchemy.engine.base.Engine {}
#      objectid    id  volume  quantite dateInstallation  \
# 0           1  None   660.0         1             None
# 1           2  None   660.0         3             None
# 2           3  None   660.0         1             None
# 3           4  None   660.0         1             None
# 4           5  None   660.0         1             None
# ..        ...   ...     ...       ...              ...
# 962       963  None     NaN         1             None
# 963       964  None     NaN         1             None
# 964       965  None     NaN         1             None
# 965       966  None     NaN         3             None
# 966       967  None     NaN         1             None
#
#                                                adresse adresseComplement  \
# 0                                             Gare tsm              None
# 1             Résidence les terrasses de saint honorat              None
# 2                                      Prince des iles              None
# 3                Avenue de lerins trottoir de l eglise              None
# 4    Avenue de lerins angle traverse magasin souvenirs              None
# ..                                                 ...               ...
# 962                       1102 avenue du maréchal juin              None
# 963                                Chemin de la plaine              None
# 964                                   Chemin du refuge              None
# 965                                   Avenue lamartine              None
# 966                                Chemin de coudouron       Déchèterie
#
#     codeInsee observations createur  ... idCategorie idTri idMarque  id  \
# 0       06138         None  chpayet  ...         1.0     1      1.0   1
# 1       06138         None  chpayet  ...         1.0     1      1.0   1
# 2       06138         None  chpayet  ...         2.0     1      1.0   1
# 3       06138         None  chpayet  ...         2.0     1      1.0   1
# 4       06138         None  chpayet  ...         2.0     1      1.0   1
# ..        ...          ...      ...  ...         ...   ...      ...  ..
# 962     06085         None  chpayet  ...         NaN     5      NaN   5
# 963     06085         None  chpayet  ...         NaN     5      NaN   5
# 964     06085         None  chpayet  ...         NaN     5      NaN   5
# 965     06085         None  chpayet  ...         NaN     5      NaN   5
# 966     06085         None  chpayet  ...         NaN     5      NaN   5
#
#       typeTri   id             nom   id             typeCollecteur  \
# 0          om  1.0  Plastic Omnium  1.0  Bac aérien avec cache bac
# 1          om  1.0  Plastic Omnium  1.0  Bac aérien avec cache bac
# 2          om  1.0  Plastic Omnium  2.0  Bac aérien sans cache bac
# 3          om  1.0  Plastic Omnium  2.0  Bac aérien sans cache bac
# 4          om  1.0  Plastic Omnium  2.0  Bac aérien sans cache bac
# ..        ...  ...             ...  ...                        ...
# 962  vêtement  NaN            None  NaN                       None
# 963  vêtement  NaN            None  NaN                       None
# 964  vêtement  NaN            None  NaN                       None
# 965  vêtement  NaN            None  NaN                       None
# 966  vêtement  NaN            None  NaN                       None
#
#                ville
# 0    Théoule-sur-Mer
# 1    Théoule-sur-Mer
# 2    Théoule-sur-Mer
# 3    Théoule-sur-Mer
# 4    Théoule-sur-Mer
# ..               ...
# 962          Mougins
# 963          Mougins
# 964          Mougins
# 965          Mougins
# 966          Mougins
#
# [967 rows x 26 columns]

# %% [markdown]
# ## Affichage des graphiques

# %%
sns.set(style="darkgrid")
plt.figure(figsize= [15, 6])
plt.title("Nombre de sites de collecteurs par ville")
sns.countplot(x="ville", data=dataCollecteurs, order=dataCollecteurs["ville"].value_counts().keys())

# %%
dataCollecteursQuantiteVille = dataCollecteurs.groupby(by=["ville"])["quantite"].sum().reset_index(name="quantite")

plt.figure(figsize= [15, 6])
plt.title("Nombre de collecteurs par ville")
sns.barplot(x="ville", y="quantite", data=dataCollecteursQuantiteVille, order=dataCollecteurs["ville"].value_counts().keys())

# %%
plt.figure(figsize= [15, 6])
plt.title("Nombre de sites de collecteurs par marque")
sns.countplot(x="nom", data=dataCollecteurs, order=dataCollecteurs["nom"].value_counts().keys())

# %%
dataCollecteursQuantiteMarque = dataCollecteurs.groupby(by=["nom"])["quantite"].sum().reset_index(name="quantite")

plt.figure(figsize= [15, 6])
plt.title("Nombre de collecteurs par marque")
sns.barplot(x="nom", y="quantite", data=dataCollecteursQuantiteMarque, order=dataCollecteurs["nom"].value_counts().keys())

# %%
plt.figure(figsize= [15, 6])
plt.title("Nombre de sites de collecteurs par volume (en L)")
sns.countplot(x="volume", data=dataCollecteurs, order=dataCollecteurs["volume"].value_counts().keys())

# %%
dataCollecteursQuantiteVolume = dataCollecteurs.groupby(by=["volume"])["quantite"].sum().reset_index(name="quantite")

plt.figure(figsize= [15, 6])
plt.title("Nombre de collecteurs par volume (en L)")
sns.barplot(x="volume", y="quantite", data=dataCollecteursQuantiteVolume, order=dataCollecteurs["volume"].value_counts().keys())

# %%
plt.figure(figsize= [20, 6])
plt.title("Nombre de sites de collecteurs par type de collecteur")
sns.countplot(x="typeCollecteur", data=dataCollecteurs, order=dataCollecteurs["typeCollecteur"].value_counts().keys())

# %%
dataCollecteursQuantiteCollecteur = dataCollecteurs.groupby(by=["typeCollecteur"])["quantite"].sum().reset_index(name="quantite")

plt.figure(figsize= [20, 6])
plt.title("Nombre de collecteurs par type de collecteur")
sns.barplot(x="typeCollecteur", y="quantite", data=dataCollecteursQuantiteCollecteur, order=dataCollecteurs["typeCollecteur"].value_counts().keys())

# %%
plt.figure(figsize= [15, 6])
plt.title("Nombre de collecteurs par type de tri")
sns.countplot(x="typeTri", data=dataCollecteurs, order=dataCollecteurs["typeTri"].value_counts().keys())

# %%
dataCollecteursQuantiteTri = dataCollecteurs.groupby(by=["typeTri"])["quantite"].sum().reset_index(name="quantite")

plt.figure(figsize= [15, 6])
plt.title("Nombre de collecteurs par type de collecteur")
sns.barplot(x="typeTri", y="quantite", data=dataCollecteursQuantiteTri, order=dataCollecteurs["typeTri"].value_counts().keys())

# %%
plt.figure(figsize= [15, 6])
plt.title("Nombre de sites de collecteurs par type de tri et par ville")
sns.countplot(x="ville", hue="typeTri", data=dataCollecteurs, order=dataCollecteurs['ville'].value_counts().keys())

# %%
dataCollecteursQuantiteTriVille = dataCollecteurs.groupby(by=["ville", "typeTri"])["quantite"].sum().reset_index(name="quantite")

plt.figure(figsize= [15, 6])
plt.title("Nombre de collecteurs par type de tri et par ville")
sns.barplot(x="ville", hue="typeTri", y="quantite", data=dataCollecteursQuantiteTriVille, order=dataCollecteurs["ville"].value_counts().keys(), hue_order=["om", "papier", "emballage", "verre", "vetement"])

# %%
plt.figure(figsize= [15, 6])
dataCollecteurs["ville"].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Répartition des sites de collecteurs par ville")
# Out:
# Text(0.5, 1.0, 'Répartition des sites de collecteurs par ville')

# %%
dataCollecteursQuantiteVille = dataCollecteursQuantiteVille.sort_values(by=['quantite'], ascending=False)
plt.figure(figsize= [15, 6])
dataCollecteursQuantiteVille["quantite"].plot(labels=dataCollecteursQuantiteVille["ville"], kind='pie', autopct='%1.1f%%')
plt.title("Répartition des collecteurs par ville")
# Out:
# Text(0.5, 1.0, 'Répartition des collecteurs par ville')

# %%
plt.figure(figsize= [15, 6])
dataCollecteurs["typeTri"].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Répartition des sites de collecteurs par type de tri")
# Out:
# Text(0.5, 1.0, 'Répartition des sites de collecteurs par type de tri')

# %%
dataCollecteursQuantiteTri = dataCollecteursQuantiteTri.sort_values(by=['quantite'], ascending=False)

plt.figure(figsize= [15, 6])
dataCollecteursQuantiteTri["quantite"].plot(labels=dataCollecteursQuantiteTri["typeTri"], kind='pie', autopct='%1.1f%%')
plt.title("Répartition des collecteurs par type de tri")
# Out:
# Text(0.5, 1.0, 'Répartition des collecteurs par type de tri')

# %%
labels = ['Ordures ménagères', 'Verre', 'Emballages', 'Vêtements', "Papier"]
explode = (0, 0.1, 0, 0, 0)  
fig, ax = plt.subplots()
ax.pie(dataCollecteurs["typeTri"].value_counts(), explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')  
plt.title("Répartition des collecteurs par type de tri")
plt.tight_layout()
plt.show()
